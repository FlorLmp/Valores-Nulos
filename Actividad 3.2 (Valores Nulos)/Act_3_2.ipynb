# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('listings.csv')           #Se subio el archivo csv
data.head(5)                                #se mostraron los primeros 5 registros
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  31840  https://www.airbnb.com/rooms/31840  20240917031426   2024-09-17
# 1  32120  https://www.airbnb.com/rooms/32120  20240917031426   2024-09-17
# 2  32180  https://www.airbnb.com/rooms/32180  20240917031426   2024-09-17
# 3  39115  https://www.airbnb.com/rooms/39115  20240917031426   2024-09-17
# 4  39165  https://www.airbnb.com/rooms/39165  20240917031426   2024-09-17
#
#             source                                      name  \
# 0  previous scrape          A Residenza Martin  Classic room
# 1      city scrape        Welcome at Corte Verde in Florence
# 2      city scrape       Charming Gem - Oltrarno City centre
# 3      city scrape            Central Double Shared Bathroom
# 4  previous scrape  Florence Central Double Private Bathroom
#
#                                          description  \
# 0  Nice, private and quiet double room, classic s...
# ...

# %%
data.info()                                 #se muestra la información de la base de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12722 entries, 0 to 12721
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            12722 non-null  int64
#  1   listing_url                                   12722 non-null  object
#  2   scrape_id                                     12722 non-null  int64
#  3   last_scraped                                  12722 non-null  object
#  4   source                                        12722 non-null  object
#  5   name                                          12722 non-null  object
#  6   description                                   12357 non-null  object
#  7   neighborhood_overview                         7415 non-null   object
#  8   picture_url                                   12722 non-null  object
# ...

# %%
data1= data.drop(['listing_url','listing_url','last_scraped','neighborhood_overview','picture_url','host_url','host_about','host_thumbnail_url','host_picture_url','host_neighbourhood','host_has_profile_pic','host_identity_verified','neighbourhood','neighbourhood_group_cleansed','bathrooms_text','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','maximum_maximum_nights','minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated','calendar_last_scraped','calculated_host_listings_count','calculated_host_listings_count_entire_homes','calculated_host_listings_count_private_rooms','calculated_host_listings_count_shared_rooms'], axis=1)
data1           #se eliminaron las columas que no se usaran
# Out:
#                         id       scrape_id           source  \
# 0                    31840  20240917031426  previous scrape
# 1                    32120  20240917031426      city scrape
# 2                    32180  20240917031426      city scrape
# 3                    39115  20240917031426      city scrape
# 4                    39165  20240917031426  previous scrape
# ...                    ...             ...              ...
# 12717  1244899380239866505  20240917031426      city scrape
# 12718  1245523314672846496  20240917031426      city scrape
# 12719  1245670462241721407  20240917031426      city scrape
# 12720  1246427901403972447  20240917031426      city scrape
# 12721  1246524294230158075  20240917031426      city scrape
#
#                                            name  \
# 0              A Residenza Martin  Classic room
# 1            Welcome at Corte Verde in Florence
# 2           Charming Gem - Oltrarno City centre
# ...

# %%
valores_nulos=data1.isnull().sum()
valores_nulos                   #se visualizan primero las columnas que tienen valores nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                     365
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                  2386
# host_response_time             1134
# host_response_rate             1134
# host_acceptance_rate            587
# host_is_superhost               752
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
valores_nulos=data1.isnull().sum().sum()
valores_nulos                           #se visualiza el total de valores nulos
# Out:
# np.int64(29911)

# %%
data1["description"]=data1["description"].fillna(method="ffill")    #el texto faltante puede ser similar al anterior, ya que probablemente pertenezcan a propiedades similares
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\2760889633.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["description"]=data1["description"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                  2386
# host_response_time             1134
# host_response_rate             1134
# host_acceptance_rate            587
# host_is_superhost               752
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["host_location"]=data1["host_location"].fillna(method="ffill")    #es probable que las ubicaciones de los anfitriones sean consistentes con registros anteriores en la base de datos
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\2697574924.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["host_location"]=data1["host_location"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time             1134
# host_response_rate             1134
# host_acceptance_rate            587
# host_is_superhost               752
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["host_response_time"]=data1["host_response_time"].fillna(method="ffill")  #si falta el tiempo de respuesta, es razonable suponer que será similar al del registro previo
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\4285316329.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["host_response_time"]=data1["host_response_time"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate             1134
# host_acceptance_rate            587
# host_is_superhost               752
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["host_response_rate"]=data1["host_response_rate"].fillna(method="ffill")  #las tasas de respuesta pueden ser similares entre registros del mismo anfitrión
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\2804669662.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["host_response_rate"]=data1["host_response_rate"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate            587
# host_is_superhost               752
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["host_acceptance_rate"]=data1["host_acceptance_rate"].fillna(method="ffill")  #similar a la tasa de respuesta, se puede asumir consistencia con el valor anterior
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\3928446163.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["host_acceptance_rate"]=data1["host_acceptance_rate"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost               752
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["host_is_superhost"]=data1["host_is_superhost"].fillna(method="ffill")    #si el valor falta, es razonable considerar que podría ser igual al del registro anterior
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\45705472.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["host_is_superhost"]=data1["host_is_superhost"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                       842
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["bathrooms"]=data1["bathrooms"].fillna(round(data["bathrooms"].mean(),1)) #la media representa el promedio de baños en las propiedades, lo cual es razonable para propiedades similares.

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                         71
# beds                            872
# amenities                         0
# ...

# %%
data1["bedrooms"]=data1["bedrooms"].fillna(round(data["bedrooms"].mean(),1))    #el promedio de habitaciones proporciona un valor razonable para propiedades similares

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                            872
# amenities                         0
# ...

# %%
data1["beds"]=data1["beds"].fillna(round(data["beds"].mean(),1))    #las camas son generalmente proporcionales a las habitaciones; la media es adecuada

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["price"]=data1["price"].fillna(0) #no es posible dar un valor de precio

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["has_availability"]=data1["has_availability"].fillna(method="ffill")  #si falta este dato, es probable que sea igual al del registro anterior
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\1386505285.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["has_availability"]=data1["has_availability"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["first_review"]=data1["first_review"].fillna(method="ffill")  #la fecha de la primera reseña podría considerarse similar a registros cercanos
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\2955235505.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["first_review"]=data1["first_review"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["last_review"]=data1["last_review"].fillna(method="ffill")    #la fecha de la última reseña puede ser cercana a la de registros anteriores
# Out:
# C:\Users\Miriam Florencia\AppData\Local\Temp\ipykernel_22460\326000287.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1["last_review"]=data1["last_review"].fillna(method="ffill")

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_rating"]=data1["review_scores_rating"].fillna(round(data["review_scores_rating"].mean(),1))    #el promedio de las calificaciones es una estimación razonable para las propiedades sin datos

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_accuracy"]=data1["review_scores_accuracy"].fillna(round(data["review_scores_accuracy"].mean(),1))  #la media refleja la precisión percibida de otras propiedades similares

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_cleanliness"]=data1["review_scores_cleanliness"].fillna(round(data["review_scores_cleanliness"].mean(),1)) #el promedio es adecuado para propiedades con estándares similares de limpieza

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_checkin"]=data1["review_scores_checkin"].fillna(round(data["review_scores_checkin"].mean(),1)) #el promedio de puntuación es razonable para la experiencia de registro

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_communication"]=data1["review_scores_communication"].fillna(round(data["review_scores_communication"].mean(),1))   #la media refleja la experiencia general de comunicación

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_location"]=data1["review_scores_location"].fillna(round(data["review_scores_location"].mean(),1))  #la media es razonable para propiedades ubicadas en zonas similares

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["review_scores_value"]=data1["review_scores_value"].fillna(round(data["review_scores_value"].mean(),1))   #representa un promedio justo para propiedades similares en precio y calidad

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["license"] =data1["license"].fillna("no disponible")      #se utiliza este ya que no es un valor sustituible como tal

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# scrape_id                         0
# source                            0
# name                              0
# description                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# neighbourhood_cleansed            0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# amenities                         0
# ...

# %%
data1["reviews_per_month"]=data1["reviews_per_month"].fillna(round(data["reviews_per_month"].mean(),1))     #usar el promedio es razonable para representar el flujo típico de reseñas mensuales

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                             0
# scrape_id                      0
# source                         0
# name                           0
# description                    0
# host_id                        0
# host_name                      0
# host_since                     0
# host_location                  0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# neighbourhood_cleansed         0
# latitude                       0
# longitude                      0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms                      0
# bedrooms                       0
# beds                           0
# amenities                      0
# price                          0
# minimum_nights                 0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12722 entries, 0 to 12721
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           12722 non-null  int64
#  1   scrape_id                    12722 non-null  int64
#  2   source                       12722 non-null  object
#  3   name                         12722 non-null  object
#  4   description                  12722 non-null  object
#  5   host_id                      12722 non-null  int64
#  6   host_name                    12722 non-null  object
#  7   host_since                   12722 non-null  object
#  8   host_location                12722 non-null  object
#  9   host_response_time           12722 non-null  object
#  10  host_response_rate           12722 non-null  object
#  11  host_acceptance_rate         12722 non-null  object
#  12  host_is_superhost            12722 non-null  object
# ...

# %%
valores_nulos=data1.isnull().sum().sum()
valores_nulos                           #se visualiza el total ahora sin valores nulos
# Out:
# np.int64(0)

# %%
data1.to_csv("Florencia_sin_nulos.csv")
